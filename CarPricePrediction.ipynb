# %%
import pandas as pd

df=pd.read_csv('Toyota.csv',index_col=0, na_values

# %%
df.head()
# Out:
#    Price   Age       KM FuelType    HP  MetColor  Automatic    CC  Doors  \
# 0  13500  23.0  46986.0   Diesel  90.0       1.0          0  2000  three
# 1  13750  23.0  72937.0   Diesel  90.0       1.0          0  2000      3
# 2  13950  24.0  41711.0   Diesel  90.0       NaN          0  2000      3
# 3  14950  26.0  48000.0   Diesel  90.0       0.0          0  2000      3
# 4  13750  30.0  38500.0   Diesel  90.0       0.0          0  2000      3
#
#    Weight
# 0    1165
# 1    1165
# 2    1165
# 3    1165
# 4    1170

# %%
import numpy as np
df.size
# Out:
# 14360

# %%
df.isnull().sum()
# Out:
# Price          0
# Age          100
# KM            15
# FuelType     100
# HP             6
# MetColor     150
# Automatic      0
# CC             0
# Doors          0
# Weight         0
# dtype: int64

# %%
samp=df.copy()

# %%
samp
# Out:
#       Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1     13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 2     13950  24.0  41711.0   Diesel   90.0       NaN          0  2000      3
# 3     14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4     13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# ...     ...   ...      ...      ...    ...       ...        ...   ...    ...
# 1431   7500   NaN  20544.0   Petrol   86.0       1.0          0  1300      3
# 1432  10845  72.0      NaN   Petrol   86.0       0.0          0  1300      3
# 1433   8500   NaN  17016.0   Petrol   86.0       0.0          0  1300      3
# 1434   7250  70.0      NaN      NaN   86.0       1.0          0  1300      3
# 1435   6950  76.0      1.0   Petrol  110.0       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# ...

# %%
samp.columns
# Out:
# Index(['Price', 'Age', 'KM', 'FuelType', 'HP', 'MetColor', 'Automatic', 'CC',
#        'Doors', 'Weight'],
#       dtype='object')

# %%
df.head()
# Out:
#    Price   Age       KM FuelType    HP  MetColor  Automatic    CC  Doors  \
# 0  13500  23.0  46986.0   Diesel  90.0       1.0          0  2000  three
# 1  13750  23.0  72937.0   Diesel  90.0       1.0          0  2000      3
# 2  13950  24.0  41711.0   Diesel  90.0       NaN          0  2000      3
# 3  14950  26.0  48000.0   Diesel  90.0       0.0          0  2000      3
# 4  13750  30.0  38500.0   Diesel  90.0       0.0          0  2000      3
#
#    Weight
# 0    1165
# 1    1165
# 2    1165
# 3    1165
# 4    1170

# %%
car_data=df.copy()

# %%
car_data.memory_usage()
# Out:
# Index        11488
# Price        11488
# Age          11488
# KM           11488
# FuelType     11488
# HP           11488
# MetColor     11488
# Automatic    11488
# CC           11488
# Doors        11488
# Weight       11488
# dtype: int64

# %%
car_data.ndim
# Out:
# 2

# %%
car_data
# Out:
#       Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1     13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 2     13950  24.0  41711.0   Diesel   90.0       NaN          0  2000      3
# 3     14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4     13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# ...     ...   ...      ...      ...    ...       ...        ...   ...    ...
# 1431   7500   NaN  20544.0   Petrol   86.0       1.0          0  1300      3
# 1432  10845  72.0      NaN   Petrol   86.0       0.0          0  1300      3
# 1433   8500   NaN  17016.0   Petrol   86.0       0.0          0  1300      3
# 1434   7250  70.0      NaN      NaN   86.0       1.0          0  1300      3
# 1435   6950  76.0      1.0   Petrol  110.0       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# ...

# %%
car_data.iloc[:,2]
# Out:
# 0       46986.0
# 1       72937.0
# 2       41711.0
# 3       48000.0
# 4       38500.0
#          ...
# 1431    20544.0
# 1432        NaN
# 1433    17016.0
# 1434        NaN
# 1435        1.0
# Name: KM, Length: 1436, dtype: float64

# %%
import numpy as np

# %%
car_data.dtypes
# Out:
# Price          int64
# Age          float64
# KM           float64
# FuelType      object
# HP           float64
# MetColor     float64
# Automatic      int64
# CC             int64
# Doors         object
# Weight         int64
# dtype: object

# %%
car_data.dtypes.value_counts()
# Out:
# float64    4
# int64      4
# object     2
# dtype: int64

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1336 non-null   float64
#  2   KM         1421 non-null   float64
#  3   FuelType   1336 non-null   object
#  4   HP         1430 non-null   float64
#  5   MetColor   1286 non-null   float64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   object
#  9   Weight     1436 non-null   int64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 123.4+ KB

# %%
car_data['Weight'].unique()
# Out:
# array([1165, 1170, 1245, 1185, 1105, 1065, 1120, 1100, 1255, 1270, 1110,
#        1195, 1180, 1075, 1130, 1275, 1060, 1115, 1265, 1260, 1125, 1155,
#        1045, 1480, 1320, 1280, 1135, 1090, 1150, 1085, 1160, 1205, 1084,
#        1140, 1095, 1025, 1119, 1080, 1121, 1615, 1067, 1040, 1030, 1055,
#        1050, 1103, 1070, 1035, 1015, 1000, 1078, 1079, 1109, 1020, 1010,
#        1114, 1172, 1094, 1083], dtype=int64)

# %%
car_data['FuelType']
# Out:
# 0       Diesel
# 1       Diesel
# 2       Diesel
# 3       Diesel
# 4       Diesel
#          ...
# 1431    Petrol
# 1432    Petrol
# 1433    Petrol
# 1434       NaN
# 1435    Petrol
# Name: FuelType, Length: 1436, dtype: object

# %%
            np.unique(car_data['KM'])
# Out:
# array([  1.,  15., 225., ...,  nan,  nan,  nan])

# %%
car_data
# Out:
#       Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1     13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 2     13950  24.0  41711.0   Diesel   90.0       NaN          0  2000      3
# 3     14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4     13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# ...     ...   ...      ...      ...    ...       ...        ...   ...    ...
# 1431   7500   NaN  20544.0   Petrol   86.0       1.0          0  1300      3
# 1432  10845  72.0      NaN   Petrol   86.0       0.0          0  1300      3
# 1433   8500   NaN  17016.0   Petrol   86.0       0.0          0  1300      3
# 1434   7250  70.0      NaN      NaN   86.0       1.0          0  1300      3
# 1435   6950  76.0      1.0   Petrol  110.0       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# ...

# %%
car_data=df.copy()

# %%
car_data
# Out:
#       Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1     13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 2     13950  24.0  41711.0   Diesel   90.0       NaN          0  2000      3
# 3     14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4     13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# ...     ...   ...      ...      ...    ...       ...        ...   ...    ...
# 1431   7500   NaN  20544.0   Petrol   86.0       1.0          0  1300      3
# 1432  10845  72.0      NaN   Petrol   86.0       0.0          0  1300      3
# 1433   8500   NaN  17016.0   Petrol   86.0       0.0          0  1300      3
# 1434   7250  70.0      NaN      NaN   86.0       1.0          0  1300      3
# 1435   6950  76.0      1.0   Petrol  110.0       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# ...

# %%
np.unique(car_data['KM'])
# Out:
# array([  1.,  15., 225., ...,  nan,  nan,  nan])

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1336 non-null   float64
#  2   KM         1421 non-null   float64
#  3   FuelType   1336 non-null   object
#  4   HP         1430 non-null   float64
#  5   MetColor   1286 non-null   float64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   object
#  9   Weight     1436 non-null   int64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 123.4+ KB

# %%
car_data['MetColor']=car_data['MetColor'].astype(object)

# %%
car_data['Automatic']=car_data['Automatic'].astype(object)

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1336 non-null   float64
#  2   KM         1421 non-null   float64
#  3   FuelType   1336 non-null   object
#  4   HP         1430 non-null   float64
#  5   MetColor   1286 non-null   object
#  6   Automatic  1436 non-null   object
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   object
#  9   Weight     1436 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 123.4+ KB

# %%
car_data['FuelType'].astype('category').nbytes
# Out:
# 1460

# %%
car_data['Doors'].replace('three',3,inplace=True)

# %%
car_data['Doors'].replace('four',4,inplace=True)

# %%
car_data['Doors'].replace('five',5,inplace=True)

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1336 non-null   float64
#  2   KM         1421 non-null   float64
#  3   FuelType   1336 non-null   object
#  4   HP         1430 non-null   float64
#  5   MetColor   1286 non-null   object
#  6   Automatic  1436 non-null   object
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   object
#  9   Weight     1436 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 123.4+ KB

# %%
car_data['Doors']=car_data['Doors'].astype('int64')

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1336 non-null   float64
#  2   KM         1421 non-null   float64
#  3   FuelType   1336 non-null   object
#  4   HP         1430 non-null   float64
#  5   MetColor   1286 non-null   object
#  6   Automatic  1436 non-null   object
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   int64
#  9   Weight     1436 non-null   int64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 123.4+ KB

# %%
car_data['Doors']
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 1431    3
# 1432    3
# 1433    3
# 1434    3
# 1435    5
# Name: Doors, Length: 1436, dtype: int64

# %%
np.unique(car_data['Doors'])
# Out:
# array([2, 3, 4, 5], dtype=int64)

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1336 non-null   float64
#  2   KM         1421 non-null   float64
#  3   FuelType   1336 non-null   object
#  4   HP         1430 non-null   float64
#  5   MetColor   1286 non-null   object
#  6   Automatic  1436 non-null   object
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   int64
#  9   Weight     1436 non-null   int64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 123.4+ KB

# %%
car_data.isnull().sum()
# Out:
# Price          0
# Age          100
# KM            15
# FuelType     100
# HP             6
# MetColor     150
# Automatic      0
# CC             0
# Doors          0
# Weight         0
# dtype: int64

# %%
car_data['FuelType'].unique()
# Out:
# array(['Diesel', nan, 'Petrol', 'CNG'], dtype=object)

# %%
car_data2=car_data.copy()

# %%
car_data2
# Out:
#       Price   Age       KM FuelType     HP MetColor Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0      1.0         0  2000      3
# 1     13750  23.0  72937.0   Diesel   90.0      1.0         0  2000      3
# 2     13950  24.0  41711.0   Diesel   90.0      NaN         0  2000      3
# 3     14950  26.0  48000.0   Diesel   90.0      0.0         0  2000      3
# 4     13750  30.0  38500.0   Diesel   90.0      0.0         0  2000      3
# ...     ...   ...      ...      ...    ...      ...       ...   ...    ...
# 1431   7500   NaN  20544.0   Petrol   86.0      1.0         0  1300      3
# 1432  10845  72.0      NaN   Petrol   86.0      0.0         0  1300      3
# 1433   8500   NaN  17016.0   Petrol   86.0      0.0         0  1300      3
# 1434   7250  70.0      NaN      NaN   86.0      1.0         0  1300      3
# 1435   6950  76.0      1.0   Petrol  110.0      0.0         0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# ...

# %%
pd.crosstab(index=car_data2['FuelType'], columns='count')
# Out:
# col_0     count
# FuelType
# CNG          15
# Diesel      144
# Petrol     1177

# %%
pd.crosstab(index=car_data2['Automatic'], columns=car_data2['FuelType'],normalize='columns', dropna=True, margins=True)
# Out:
# FuelType   CNG  Diesel    Petrol       All
# Automatic
# 0          1.0     1.0  0.937978  0.945359
# 1          0.0     0.0  0.062022  0.054641

# %%
car_data2.select_dtypes(exclude=['object'])
# Out:
#       Price   Age       KM     HP    CC  Doors  Weight
# 0     13500  23.0  46986.0   90.0  2000      3    1165
# 1     13750  23.0  72937.0   90.0  2000      3    1165
# 2     13950  24.0  41711.0   90.0  2000      3    1165
# 3     14950  26.0  48000.0   90.0  2000      3    1165
# 4     13750  30.0  38500.0   90.0  2000      3    1170
# ...     ...   ...      ...    ...   ...    ...     ...
# 1431   7500   NaN  20544.0   86.0  1300      3    1025
# 1432  10845  72.0      NaN   86.0  1300      3    1015
# 1433   8500   NaN  17016.0   86.0  1300      3    1015
# 1434   7250  70.0      NaN   86.0  1300      3    1015
# 1435   6950  76.0      1.0  110.0  1600      5    1114
#
# [1436 rows x 7 columns]

# %%
car_data2.select_dtypes
# Out:
# <bound method DataFrame.select_dtypes of       Price   Age       KM FuelType     HP MetColor Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0      1.0         0  2000      3
# 1     13750  23.0  72937.0   Diesel   90.0      1.0         0  2000      3
# 2     13950  24.0  41711.0   Diesel   90.0      NaN         0  2000      3
# 3     14950  26.0  48000.0   Diesel   90.0      0.0         0  2000      3
# 4     13750  30.0  38500.0   Diesel   90.0      0.0         0  2000      3
# ...     ...   ...      ...      ...    ...      ...       ...   ...    ...
# 1431   7500   NaN  20544.0   Petrol   86.0      1.0         0  1300      3
# 1432  10845  72.0      NaN   Petrol   86.0      0.0         0  1300      3
# 1433   8500   NaN  17016.0   Petrol   86.0      0.0         0  1300      3
# 1434   7250  70.0      NaN      NaN   86.0      1.0         0  1300      3
# 1435   6950  76.0      1.0   Petrol  110.0      0.0         0  1600      5
#
#       Weight
# 0       1165
# ...

# %%
car_data2.corr()
# Out:
#            Price       Age        KM        HP        CC     Doors    Weight
# Price   1.000000 -0.878407 -0.574720  0.309902  0.165067  0.185326  0.581198
# Age    -0.878407  1.000000  0.512735 -0.157904 -0.120706 -0.157027 -0.464299
# KM     -0.574720  0.512735  1.000000 -0.335285  0.299993 -0.036191 -0.026271
# HP      0.309902 -0.157904 -0.335285  1.000000  0.053758  0.097162  0.086737
# CC      0.165067 -0.120706  0.299993  0.053758  1.000000  0.126768  0.651450
# Doors   0.185326 -0.157027 -0.036191  0.097162  0.126768  1.000000  0.302618
# Weight  0.581198 -0.464299 -0.026271  0.086737  0.651450  0.302618  1.000000

# %%
print(corr_matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-35109ce1755c> in <module>
# ----> 1 print(corr_matrix)
#
# NameError: name 'corr_matrix' is not defined

# %%
# Out:
#       Price   Age       KM FuelType     HP MetColor Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0      1.0         0  2000      3
# 1     13750  23.0  72937.0   Diesel   90.0      1.0         0  2000      3
# 2     13950  24.0  41711.0   Diesel   90.0      NaN         0  2000      3
# 3     14950  26.0  48000.0   Diesel   90.0      0.0         0  2000      3
# 4     13750  30.0  38500.0   Diesel   90.0      0.0         0  2000      3
# ...     ...   ...      ...      ...    ...      ...       ...   ...    ...
# 1431   7500   NaN  20544.0   Petrol   86.0      1.0         0  1300      3
# 1432  10845  72.0      NaN   Petrol   86.0      0.0         0  1300      3
# 1433   8500   NaN  17016.0   Petrol   86.0      0.0         0  1300      3
# 1434   7250  70.0      NaN      NaN   86.0      1.0         0  1300      3
# 1435   6950  76.0      1.0   Petrol  110.0      0.0         0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# ...
